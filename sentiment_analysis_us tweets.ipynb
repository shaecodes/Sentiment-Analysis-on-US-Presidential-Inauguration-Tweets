# %%
import pandas as pd
import os

# %%
tweets = pd.read_excel("tweets_data.xlsx")
tweets
# Out:
#                            created_at  \
# 0      Wed Jan 20 23:59:59 +0000 2021
# 1      Wed Jan 20 23:59:58 +0000 2021
# 2      Wed Jan 20 23:59:58 +0000 2021
# 3      Wed Jan 20 23:59:58 +0000 2021
# 4      Wed Jan 20 23:59:57 +0000 2021
# ...                               ...
# 44297  Wed Jan 20 17:47:49 +0000 2021
# 44298  Wed Jan 20 17:47:48 +0000 2021
# 44299  Wed Jan 20 17:47:48 +0000 2021
# 44300  Wed Jan 20 17:47:48 +0000 2021
# 44301  Wed Jan 20 17:47:47 +0000 2021
#
#                                                     text  \
# 0      Feeling happy and hopeful for all my American ...
# 1      Biden might not be a magical saviour but he co...
# 2      WE DID IT JOE!! \nYOUâ€™RE gonnandjfndndhebehr...
# 3      #JoeBiden : A better person, a better man, a b...
# 4      Girl Crushing on #KamalaHarris while at the sa...
# ...                                                  ...
# 44297  I wonder if scumbag Dems are as completely ama...
# ...
